# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    # MSE = 取實際值-預測值的平方後累加m次, 最後除上m次
    mse = MSE = sum(np.square(pow(y - y_hat, 2))) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 175674.104
# The Mean absolute error is 11.795

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# 主題：Data Science Bowl 2017
# 來源：Competitions
# 1.
# 現今許多醫院需要能夠判讀癌症病徵的機器學習人才，所挑選之競賽內容具有許多可用於lung cancer classification的相關演算法，
# 如基礎紋理的特徵提取演匴法LBP、GLCM，和卷積神經網路Mask RCNN、3D CNN等，並了解如何操作CT Image在Hounsfield Unit(HU)
# 不同閥值間的變化。此競賽教程裡有許多CT Preprocessing的例子，可以加速小弟我在醫學影像的學習過程。
#
# 2.
# data來自競賽網頁所提供，採用直接下載方式蒐集，已無法下載的連結另外尋找外部連結下載。
#
# 3.
# 資料型態包含肺部CT圖像文件(DICOM)、癌症基礎事實對照表(CSV)、解密密鑰(TXT)
# stage1.7z [DICOM]- 比賽的完整數據集，包括訓練和測試集(目前已無法下載，需尋找外部連結)。
# stage1_labels.csv [CSV]- 訓練集圖像的癌症基礎事實
# stage1_sample_submission.csv [CSV]- 顯示階段1的提交格式。您還應該使用此文件來確定哪些患者屬於階段1的排行榜集。
# sample_images.7z  [DICOM]- 完整數據集的較小子集，為希望在下載大文件之前預覽圖像的人提供。
# data_password.txt [TXT]- 包含圖像文件的解密密鑰
#
# 4.
# 這樣競賽的目標問題是創建一種自動化方法，該方法能夠在掃描日期後的一年內確定患者是否將被診斷患有肺癌。
# 以病理診斷證實ground truth labels，提交每一位患者的預測概率。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 1.
# 主要目標：提升業績
# 需以客人角度為出發點，先以載客App中的乘客滿意度調查整體服務品質，建立顧客滿意指標CSI，透過乘客的性別與路線和搜尋紀錄推薦
# 個性化廣告，配合優惠費率來促進乘客搭車。
#
# 2.
# /資料     /目的        /如何蒐集
# 載客性別-->統計男女比-->會員設定
# 載客路線-->紀錄顧客常用路線-->GPS紀錄
# 搜尋紀錄-->設置廣告開發更多顧客-->獲取搜尋權限
# 滿意度-->提升整體服務品質-->會員設定
#
# *可能遇到問題：
# 蒐集之資料如何分析
# 顧客滿意策略CSS規劃
# 車隊司機素質參差不齊
# 優惠費率是否符合成本
# 到點載客時間如何掌握
# 路線規劃如何最佳化
#
# 3.
# 載客性別 [CSV]
# 載客路線 [CSV + Image]
# 近期搜尋 [CSV]
# 滿意度 [CSV]
#
# 4.
# *透過分析獲得之資料庫與App評分回覆機制達到以下三項滿足：
# 系統滿足
# 服務滿足
# 費率滿足
